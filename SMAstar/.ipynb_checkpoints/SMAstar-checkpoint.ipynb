# %% [markdown]
# Code credits - **Mukesh Prasanna**

# %%
from collections import defaultdict

class Graph :
    def __init__(self) -> None:
        self.edges = defaultdict(dict)
        self.nodes = defaultdict(int)

    def addNode(self, x, hval) :
        self.nodes[x] = hval 
    
    def addEdge(self, u, v, w) :
        self.edges[u][v] = w

    def calcCost(self, cost, path) :
        return cost-self.nodes[path[-2]] + self.edges[path[-2]][path[-1]] + self.nodes[path[-1]]
    
    def smastar(self, source, goal, bound) :

        if source==goal :
            print(source)
            return
        
        if bound==1 :
            print('Goal not found')
            return
        
        bound+=1
        
        frontier = []
        frontier.append((self.nodes[source], (source,)))

        visited = defaultdict(list)
        mem = 1

        while frontier :
            
            if mem==bound :
                frontier.pop(-1)
                mem-=1
            
            if not frontier :
                print('Failure')
                return
            
            cost, path = frontier.pop(0)
            added = False
            for i in self.edges[path[-1]] :
                if i not in visited[path[-1]] :
                    npath = path+(i,)
                    ncost = self.calcCost(cost, npath)
                    frontier.append((ncost, npath))
                    visited[path[-1]].append(i)
                    mem+=1
                    added = True
                    if mem==bound :
                        break 
                
            
            if not added :
                print('Failure')
                return
            
            frontier.sort()
            if frontier[0][1][-1]==goal :
                print('Path :', frontier[0][1])
                print('Cost :', frontier[0][0])
                return 
            


g = Graph()

for _ in range(int(input('Enter the number of nodes : '))) :
    x, hval = input('Enter the node and heuristic value : ').split()
    g.addNode(x, int(hval))
    
for _ in range(int(input('\nEnter the number of edges : '))) :
    u,v,w = input('Enter the source and destination of edge : ').split()
    g.addEdge(u,v,int(w))
    
source, goal = input('Enter the source and goal nodes : ').split()
bound = int(input('Enter memory bound : '))
g.smastar(source, goal, bound)
# Out:
# Enter the number of nodes : 10
# Enter the node and heuristic value : a 8
# Enter the node and heuristic value : b 10
# Enter the node and heuristic value : c 4
# Enter the node and heuristic value : d 15
# Enter the node and heuristic value : e 14
# Enter the node and heuristic value : f 12
# Enter the node and heuristic value : g 11
# Enter the node and heuristic value : h 2
# Enter the node and heuristic value : i 0
# Enter the node and heuristic value : j 2
#
# Enter the number of edges : 11
# Enter the source and destination of edge : a b 1
# Enter the source and destination of edge : a c 2
# Enter the source and destination of edge : b d 7
# Enter the source and destination of edge : b e 4
# Enter the source and destination of edge : b f 5
# Enter the source and destination of edge : c g 4
# Enter the source and destination of edge : c h 3
# Enter the source and destination of edge : c i 6
# Enter the source and destination of edge : c j 8
# Enter the source and destination of edge : g h 1
# Enter the source and destination of edge : h i 3
# Enter the source and goal nodes : a i
# Enter memory bound : 4
# Path : ('a', 'c', 'h', 'i')
# Cost : 8

# %%
from collections import defaultdict

class Graph :
    def __init__(self) -> None:
        self.edges = defaultdict(dict)
        self.nodes = defaultdict(int)

    def addNode(self, x, hval) :
        self.nodes[x] = hval 
    
    def addEdge(self, u, v, w) :
        self.edges[u][v] = w

    def calcCost(self, cost, path) :
        return cost-self.nodes[path[-2]] + self.edges[path[-2]][path[-1]] + self.nodes[path[-1]]
    
    def smastar(self, source, goal, bound) :

        if source==goal :
            print(source)
            return
        
        if bound==1 :
            print('Goal not found')
            return
        
        bound+=1
        
        frontier = []
        frontier.append((self.nodes[source], (source,)))

        visited = defaultdict(list)
        mem = 1

        while frontier :
            
            if mem==bound :
                frontier.pop(-1)
                mem-=1
            
            if not frontier :
                print('Failure')
                return
            
            cost, path = frontier.pop(0)
            added = False
            for i in self.edges[path[-1]] :
                if i not in visited[path[-1]] :
                    npath = path+(i,)
                    ncost = self.calcCost(cost, npath)
                    frontier.append((ncost, npath))
                    visited[path[-1]].append(i)
                    mem+=1
                    added = True
                    if mem==bound :
                        break 
                
            
            if not added :
                print('Failure')
                return
            
            frontier.sort()
            if frontier[0][1][-1]==goal :
                print('Path :', frontier[0][1])
                print('Cost :', frontier[0][0])
                return 
            


g = Graph()

for _ in range(int(input('Enter the number of nodes : '))) :
    x, hval = input('Enter the node and heuristic value : ').split()
    g.addNode(x, int(hval))
    
for _ in range(int(input('\nEnter the number of edges : '))) :
    u,v,w = input('Enter the source and destination of edge : ').split()
    g.addEdge(u,v,int(w))
    
source, goal = input('Enter the source and goal nodes : ').split()
bound = int(input('Enter memory bound : '))
g.smastar(source, goal, bound)
# Out:
# Enter the number of nodes : 10
# Enter the node and heuristic value : s 180
# Enter the node and heuristic value : a 70
# Enter the node and heuristic value : b 95
# Enter the node and heuristic value : c 110
# Enter the node and heuristic value : d 50
# Enter the node and heuristic value : e 40
# Enter the node and heuristic value : f 80
# Enter the node and heuristic value : h 20
# Enter the node and heuristic value : g 0
# Enter the node and heuristic value : i 90
#
# Enter the number of edges : 15
# Enter the source and destination of edge : s a 2
# Enter the source and destination of edge : s b 5
# Enter the source and destination of edge : s c 10
# Enter the source and destination of edge : a d 1
# Enter the source and destination of edge : b d 10
# Enter the source and destination of edge : b c 15
# Enter the source and destination of edge : d e 3
# Enter the source and destination of edge : c f 20
# Enter the source and destination of edge : e f 15
# Enter the source and destination of edge : e h 4
# Enter the source and destination of edge : f i 15
# Enter the source and destination of edge : f g 12
# Enter the source and destination of edge : f h 13
# Enter the source and destination of edge : h g 2
# Enter the source and destination of edge : i g 20
# Enter the source and goal nodes : s g
# Enter memory bound : 5
# Failure
